# %%
#-*- coding: utf-8 -*-
# author : Takuro Yamazaki
# description : アルゴリズムごとの協調行動の違い

import os
from collections import OrderedDict

"""simulation world"""
from world import synchro_world

"""network"""
from networks import network_utils

"""agent"""
# defaultはこの4種類にしよう
from agent import WoLF_PHC_Agent as wpa
from agent import Q_Learning_Agent as ql
from agent import Actor_Critic_Agent as aca
from agent import SARSA_Agent as sarsa

"""payoff matrix"""
from world.payoff_matrix import *

graph_prefix = "../src/networks/"

# graphの定義
cG = network_utils.graph_generator.complete_graph
pcG = network_utils.graph_generator.powerlaw_cluster_graph

W = synchro_world.synchro_world(100, 1000, (2, -2, 2, 2), pcG, aca.Actor_Critic_Agent, altered_func=[2,-10,2,10])
W.run()

print('done!!')
# Out:
#  50%|█████     | 504/1000 [00:27<00:27, 18.28it/s]
# matrix altered!!
# 100%|██████████| 1000/1000 [00:54<00:00, 18.42it/s]
# done!!

# %%
# reverse
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.coop_per_df[0])
plt.ylim((0, 1.0))
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.q_df[0])
plt.plot(np.arange(1000), W.q_df[1])
plt.legend()
    
plt.show()

# %%
# kakudai
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.coop_per_df[0])
plt.ylim((0, 1.0))
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.q_df[0])
plt.plot(np.arange(1000), W.q_df[1])
plt.legend()
    
plt.show()

# %%
# x kaishou
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.coop_per_df[0])
plt.ylim((0, 1.0))
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.q_df[0])
plt.plot(np.arange(1000), W.q_df[1])
plt.legend()
    
plt.show()

# %%
# x kakudai
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.coop_per_df[0])
plt.ylim((0, 1.0))
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1000), W.q_df[0])
plt.plot(np.arange(1000), W.q_df[1])
plt.legend()
    
plt.show()
